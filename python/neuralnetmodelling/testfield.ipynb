# %%
class_weights_option1 = {
    0: 0.1,  # Lower weight for Class 0 (e.g., the majority class)
    1: 0.9   # Higher weight for Class 1 (e.g., the minority class)
}

print("Class Weights Option 1 (more weight to Class 1):")
print(class_weights_option1)
# Out:
# Class Weights Option 1 (more weight to Class 1):
# {0: 0.1, 1: 0.9}

# %%
import numpy as np

arr = np.array([4, 2, 3, 1, 4])
value = 4

first_index = np.where(arr == value)[0]
print(first_index)  # Output: 0
# Out:
# [0 4]
